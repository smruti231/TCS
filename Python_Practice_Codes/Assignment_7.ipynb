# %%
# Change the line opacity in Matplotlib

import matplotlib.pyplot as plt
x_values = [2, 4, 6]
y_values = [2, 4, 6]

plt.plot(x_values, y_values, "red", linewidth=5, alpha=0.4)
plt.plot(x_values, y_values, "black", linewidth=2)

# %%
# Increase the thickness of a line with Matplotlib

import matplotlib.pyplot as plt
places = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]
literacy_rate = [100, 98, 90, 85, 75, 50, 30, 45, 65, 70]
female_literacy_rate = [95, 100, 50, 60, 85, 80, 75, 99, 70, 30]
plt.xlabel("Places")
plt.ylabel("Percentage")
plt.plot(places, literacy_rate, color = 'blue', linewidth=6, label = "Literacy rate")
plt.plot(places, female_literacy_rate, color = 'fuchsia', linewidth=4, label = "Female Literacy rate")
plt.legend(loc = 'lower left', ncol = 1)

# %%
# Plot line graph from NumPy array

import numpy as np
import matplotlib.pyplot as plt
x = np.arange(1, 30)
y = x * x * x
plt.title("Line graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x, y, color ="yellow")
plt.show()

# %%
# How to Fill Between Multiple Lines in Matplotlib?

# color between the curve of the mathematical function f(x) = sin(x)
import pylab as plt
import numpy as np
x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2 * np.pi * x)
y2 = 0.8 * np.sin(4 * np.pi * x)
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex = True, figsize = (6,6))
ax1.fill_between(x,y1)
ax1.set_title('Fill between y1 and 0')
ax2.fill_between(x,y1,1)
ax2.set_title('Fill between y1 and 1')
ax3.fill_between(x,y1,y2)
ax3.set_title('Fill between y1 and y2')
ax3.set_xlabel('x')
fig.tight_layout()
